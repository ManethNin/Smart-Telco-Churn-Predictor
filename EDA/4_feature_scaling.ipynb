# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from enum import Enum
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df = pd.read_csv('./processed/feature_encoded.csv')
df
# Out:
#       customerID  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0     7590-VHVEG              0        1           0       1             0
# 1     5575-GNVDE              0        0           0      34             1
# 2     3668-QPYBK              0        0           0       2             1
# 3     7795-CFOCW              0        0           0      45             0
# 4     9237-HQITU              0        0           0       2             1
# ...          ...            ...      ...         ...     ...           ...
# 7027  6840-RESVB              0        1           1      24             1
# 7028  2234-XADUH              0        1           1      72             1
# 7029  4801-JZAZL              0        1           1      11             0
# 7030  8361-LTMKD              1        1           0       4             1
# 7031  3186-AJIEK              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
for col in df.columns:
    print(f"{col}: {df[col].unique()}\n")
# Out:
# customerID: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
#
# SeniorCitizen: [0 1]
#
# Partner: [1 0]
#
# Dependents: [0 1]
#
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
#
# PhoneService: [0 1]
#
# PaperlessBilling: [1 0]
#
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
#
# TotalCharges: [  29 1889  108 ... 1990 7362 6844]
#
# Churn: [0 1]
#
# service_adoption_score: [1 3 5 4 6 2 8 7 0]
#
# tenure_bins: [1 3 2]
#
# gender_Female: [ True False]
#
# gender_Male: [False  True]
#
# MultipleLines_No: [False  True]
#
# MultipleLines_No phone service: [ True False]
#
# MultipleLines_Yes: [False  True]
#
# InternetService_DSL: [ True False]
#
# InternetService_Fiber optic: [False  True]
#
# InternetService_No: [False  True]
#
# ...

# %%
columns_needing_scaling = [
    'MonthlyCharges', 'tenure', 'TotalCharges']

for col in columns_needing_scaling:
    scaler = StandardScaler()
    df[col] = scaler.fit_transform(df[col].values.reshape(7032,1))

# %%
df
# Out:
#       customerID  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0     7590-VHVEG              0        1           0 -1.280248             0
# 1     5575-GNVDE              0        0           0  0.064303             1
# 2     3668-QPYBK              0        0           0 -1.239504             1
# 3     7795-CFOCW              0        0           0  0.512486             0
# 4     9237-HQITU              0        0           0 -1.239504             1
# ...          ...            ...      ...         ...       ...           ...
# 7027  6840-RESVB              0        1           1 -0.343137             1
# 7028  2234-XADUH              0        1           1  1.612573             1
# 7029  4801-JZAZL              0        1           1 -0.872808             0
# 7030  8361-LTMKD              1        1           0 -1.158016             1
# 7031  3186-AJIEK              0        0           0  1.368109             1
#
# ...

# %%
df.to_csv('./processed/feature_scaled.csv', index=False)
df
# Out:
#       customerID  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0     7590-VHVEG              0        1           0 -1.280248             0
# 1     5575-GNVDE              0        0           0  0.064303             1
# 2     3668-QPYBK              0        0           0 -1.239504             1
# 3     7795-CFOCW              0        0           0  0.512486             0
# 4     9237-HQITU              0        0           0 -1.239504             1
# ...          ...            ...      ...         ...       ...           ...
# 7027  6840-RESVB              0        1           1 -0.343137             1
# 7028  2234-XADUH              0        1           1  1.612573             1
# 7029  4801-JZAZL              0        1           1 -0.872808             0
# 7030  8361-LTMKD              1        1           0 -1.158016             1
# 7031  3186-AJIEK              0        0           0  1.368109             1
#
# ...
